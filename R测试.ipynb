# %%
library(Cairo)
options(jupyter.plot_mimetypes = "image/png")
Cairo.capabilities()
# Out:
#    png   jpeg   tiff    pdf    svg     ps    x11    win raster
#   TRUE  FALSE  FALSE   TRUE   TRUE   TRUE   TRUE  FALSE   TRUE

# %%
library(Cairo)
library(ggplot2)
#options(repr.plot.width = 8, repr.plot.height = 8)
qplot(Sepal.Length, Petal.Length, data = iris)

# %%
#options(repr.plot.width = 6, repr.plot.height = 6)
par(pin=c(1,3), mai=c(2,2,2,2))

a = data.frame(x=rnorm(10),y=rnorm(10))
plot(a$x, a$y,main='中文显示测试',xlab='this is x axis', ylab='这是y轴')

# %%
#options(jupyter.plot_mimetypes = "image/png")
library("ggplot2")
set.seed(42)
n <- 1000
p <- ggplot(data.frame(x = rnorm(n), y = rnorm(n)), aes(x=x, y=y)) + 
  geom_point(alpha = 0.25, size = 1, colour = "blue") +
  geom_density2d(colour = "red")

options(repr.plot.width = 8, repr.plot.height = 3)
p + ggtitle(sprintf(
    "Plot width <> %s, plot height <> %s", 
    getOption("repr.plot.width"),
    getOption("repr.plot.height")
))


options(repr.plot.width = 6, repr.plot.height = 6)
p + ggtitle(sprintf(
    "Plot width = %s, plot height = %s", 
    getOption("repr.plot.width"),
    getOption("repr.plot.height")
))
